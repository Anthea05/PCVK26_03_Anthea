# %% [markdown]
# <a href="https://colab.research.google.com/github/Anthea05/PCVK26_03_Anthea/blob/main/P1_TugasD2_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pengolahan Citra dan Visi Komputer – Jurusan Teknologi Informasi
#
# ### Langkah (Step) 1:
#
# Pada code awal, beberapa library yang akan digunakan adalah: **numpy, pandas, cv2, skimage, PIL, matplotlib**
#
# --Bahasa--
#
# --English--
# * [Numpy](https://numpy.org/) is an array manipulation library, used for linear algebra, Fourier transform, and random number capabilities.
# * [Pandas](https://pandas.pydata.org/) is a library for data manipulation and data analysis.
# * [CV2](https://opencv.org/) is a library for computer vision tasks.
# * [Skimage](https://scikit-image.org/) is a library which supports image processing applications on python.
# * [Matplotlib](https://matplotlib.org/) is a library which generates figures and provides graphical user interface toolkit.

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ### Langkah (Step) 2:
#
# Baca Image dari URLs - Read Image From URLs
#
# --Bahasa--
#
# Pada Langkah ini kita akan membaca image dari URLs, menampilkannya menggunakan OpenCV, perhatikan ada perbedaan ketika membuka image dalam RGB dan BGR. Channel Warna default untuk OpenCV adalah BGR.
#
# --English--
#
# In this step we will read images from urls, and display them using openCV, please note the difference when reading image in RGB and BGR format. The default input color channels are in BGR format for openCV. RGB?

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://picsum.photos/800/571"]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                           #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)  #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)   #convert color to RGB
  final_frame = cv.hconcat((image, image_2))       #concatenate image
  cv2_imshow(final_frame)                          #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image
for y in range(lebar):
    image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# PERTANYAAN PRAKTIKUM D2
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# Karena google collab memungkinkan eksekusi kode Python secara interaktif tanpa perlu instalasi lokal. Selain itu google colab juga menyediakan akses GPU dan TPU secara gratis, jadi tidak perlu menggunakan perangkat keras mahal.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan?
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?  Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini? iya, kegunaannya untuk menyelaraskan ukuran gambar yang diambil dari internet. apanila kode tersebut tidak dipakai, maka yang keluar akan ukuran gambar asli dari internet
#
# 4. Perhatikan potongan kode progam berikut :
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# kombinasi angka tersebut merepresentasikan warna putih. mengubah nilai pixel pada baris tengah (tinggi/2) dan kolom y jadi putih. Karena ini dilakukan di dalam loop for y in range(lebar), hasilnya adalah garis horizontal putih solid yang melintang persis di tengah gambar (satu pixel tebal), karena tiap kolom di baris tengah itu diwarnai putih satu per satu.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# Pixel adalah unit terkecil yang membentuk gambar digital, tiap pixel mwnyimpan informasi warna (nilai kanal RGB/BGR). sedanglan resolusi gambar ditentukan dari jumlah pixel yang menyusun gambar tersebut, biasa ditulis sebagai lebar × tinggi. Jadi semakin banyak jumlah pixel per satuan luas (resolusi tinggi), gambar bisa menyimpan detail lebih halus karena tiap objek kecil di gambar direpresentasikan oleh lebih banyak pixel, jadi transisi warna/bentuknya lebih mulus dan nggak keliatan kotak-kotak.

# %% [markdown]
# Tugas Praktikum 2

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for x in range(tinggi):
    image_3[x, int((lebar)/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for i in range(tinggi):
    # diagonal utama: kiri-atas ke kanan-bawah
    j1 = int(i * lebar / tinggi)
    image_3[i, j1] = [255,255,255]

    # diagonal anti: kanan-atas ke kiri-bawah
    j2 = int(lebar - 1 - (i * lebar / tinggi))
    image_3[i, j2] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

panjang_garis = 120
mulai = int(lebar/2) - int(panjang_garis/2)
akhir = int(lebar/2) + int(panjang_garis/2)

for y in range(mulai, akhir):
    image_3[int(tinggi/2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# posisi & ukuran kotak (bebas ditentukan)
baris_mulai, baris_akhir = 20, 100
kolom_mulai, kolom_akhir = 80, 300

for i in range(baris_mulai, baris_akhir):
    for j in range(kolom_mulai, kolom_akhir):
        image_4[i, j] = [255,255,255]

cv2_imshow(image_4)
# Out:
# <PIL.Image.Image image mode=RGB size=400x286>
